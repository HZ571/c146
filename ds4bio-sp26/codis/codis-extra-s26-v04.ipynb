# %% [markdown]
# ***
# ## Bonus and Extra Credit Mini-Projects

# %% [markdown]
# Most assignments in this course will include optional extra credit questions. These questions are designed as starting points for you to explore more free-form mini projects. Therefore, there is no skeleton code and minimal guidance for these questions. You are encouraged to go beyond the scope of the question or adapt the question as necessary to answer your own scientific questions of interest. You are welcome to create as many coding cells as you would like.
#
# #### Notes:
#
# * You may work individually or in a group of any size with any members from the class.
# * Use of AI is permitted for answering these questions; all use of AI must be documented and the logs must be submitted.
# * In order to get bonus or extra credit for these questions, you must make a compelling effort (as judged by the grader). As a rule of thumb:
#     * 5 points will be awarded for answers that are ~1-2 orders of magnitude more complex and sophisticated than the base lab
#     * 2 points will be awarded for answers that are ~5x more complex and sophisticated than the base lab
#     * 1 point will be awarded for substantial work that does not meet these criteria
#
# #### Guidelines for completion:
#
# The questions below have been organized by topic for easier reading. You may answer any number of the following questions across any of the topics. Choose questions which are interesting to you!
#
# Your submission must include a brief report that has a summary of your methodology and your findings, highlighting key results and any interesting observations. The length of the report does not matter, as long as it answers all of the following questions:
# - What was your scientific goal?
# - What role did AI have in the project? What did you learn about using the AI from its use in this project?
# - What methods did you use and why?
# - What were the key results you found for each method you implemented?
# - Were there any limitations in your methods?
# - What additional observations or comments can you make on your findings? What is the greater biological relevance or implication?
# - Are there any additional questions you would want to explore?

# %% [markdown]
# <font color = #d14d0f>**Topic 1: Group Variation**</font>
#
# The original `raw_profiles` DataFrame includes a column `"Group"`, which contains the values `['Cauc', 'Hisp', 'AfAm', 'Asian']`.
#
# Q1. How could someone's group affect their probability of being a match or close match to someone else in the CODIS data? Explore the data and create visualization or other supporting statistics to build your argument. What would the implications be for forensic statistics?
#
# Q2. Explore how STR profiles vary across groups using the `euclideanDist` function. How much variation is there within and between different ancestries? Beyond this, could group be predicted from STR profile?
#
# Q3. What do these group terms correspond to, either culturally or biologically? Explore their meaning and their appropriateness as a way to classify CODIS data. Consider, for example: how do they get assigned? Do they correspond with genetic ancestry? If not, are they appropriate as a way to categorize biological data, such as STRs?

# %% [markdown]
# <font color = #d14d0f>**Topic 2: Probability of Matching**</font>
#
# As a reminder, most loci in this dataset are named as XXXX and XXXX.1. These represent the same locus on the homologous chromosomes. By convention, the smaller number of STR counts is in the XXXX column, and the larger number of STR counts is in the XXXX.1 column.
#
# Within each locus, there are distinct distributions, rather than each allele being equally likely. Furthermore, despite the fact that the CODIS alleles have been selected to not have linkage, they are nevertheless not independent.
#
# Q4. Explore the correlations between loci and alleles, and explain why they don't have independence.
#
# Q5. Could CODIS STR data be used to infer the degree of relation between two individuals? What considerations would need to be made to do so? As one aspect to consider, look up the concept of “identity by descent.”
#
# Q6. In question 4, we assumed each fingerprint was equally likely (i.e there was a uniform distribution of each allele combination). Now, consider the frequencies of each allele combination.  In this case, what is the probability of two individuals having a matching fingerprint?
#
# Q7. How many people would need to be in a population in order for there to be a >50% chance of at least two people having identical fingerprints, assuming all alleles are equally likely? Assume there are no monozygotic twins, no other genetic relationships, all STRs are independent, and no genetic structure whatsoever.

# %% [markdown]
# <font color = #d14d0f>**Topic 3: Distance Metrics and Discriminatory Power**</font>
#
# Q8. The FBI expanded from 13 to 20 CODIS core loci in 2017. Using the full `raw_profiles` dataset (which includes all 20 loci), quantify how much the discriminatory power of DNA fingerprinting improves with the additional 7 loci. How does the match probability change? How does the distribution of pairwise Euclidean distances shift? Was this expansion warranted?
#
# Q9. The base lab uses Euclidean distance to compare STR profiles. Explore at least one alternative distance or similarity metric (e.g., Manhattan distance, Hamming distance on discretized profiles, or a custom metric that weights loci by their allelic diversity). How do the results of Questions 5 and 6 change? Which metric do you think is most appropriate for comparing STR profiles, and why?
#
# Q10. The CODIS dataset used in this lab is a relatively small sample. Using resampling or bootstrapping, explore how stable the allele frequency estimates and match probabilities are. What can you say about how large the reference database would need to be for the probability estimates to be reliable? How does removing or oversampling particular groups affect the calculated match probabilities?

# %%
#YOUR CODE HERE. ADD ADDITIONAL CODE CELLS AS NEEDED.

# %% [markdown]
# **EXTRA CREDIT REPORT: [insert project choice here]** <br>
#
# *DOUBLE-CLICK TO EDIT THIS CELL AND TYPE YOUR REPORT*

# %% [markdown]
# # [ds4Bio] STR Matching; AI-assisted coding: Blue Teaming
# ### Data Science for Biology
# **Notebook developed by:** *Jeremy Marcus*<br>
# **Supervised by:** *Steven E. Brenner*
#
#
# Last week, we used generative AI to produce code to count STR repeats in a DNA sequence and to match STR profiles, and wrote validation code for testing the functionality of your solutions. Across this class period and the next, we will be performing adversarial testing of each other's code, known as "red teaming".
#
# Through this process, we will identify ways to write better specifications for code, create better validation tests, and more effectively utilize AI tools.
#
# ***

# %% [markdown]
# #### **GROUP PROJECT**
#
# This project must be completed collaboratively with your group and submitted together. All members must contribute for each part of the lab.
#
# Below, please list your group number and the names of the team members:

# %% [markdown]
# Group Number:
#
# Group Members:
#
# * LIST
# * MEMBERS
# * HERE

# %% [markdown]
# ___
# ### AI Overview
#
# #### Use of AI
#
# Throughout this and future labs, we will be explicit about where use of AI is permitted. There will be three possible options, which will be stated up front for each question:
#
# * <font color = #0fd12c>**AI PERMITTED**</font>
# * <font color = #d1b70f>**AI REQUIRED**</font>
# * <font color = #d14d0f>**NO AI**</font>
#
# Any time you use AI to generate code, ***you are expected to understand what the code is doing***. You may be asked to describe your code.
#
# #### Exporting Chats
#
# When AI tools are used to assist in solving a problem, we will ask for transcripts of any chat sessions as a PDF. Unfortunately, getting Gemini to print a PDF of a chat session while using a CalNet account is not a trivial operation. Here is our suggested solution:
#
# 1. Click the `Tools` button at the bottom of the chat box.
# 2. Select `Canvas`.
# 3. Copy and paste the following into Gemini:
#
# > Please transcribe our entire conversation word-for-word into a new Canvas document
#
# 4. Print to PDF
#
# Alternatively, there are browser-specific extensions that enable chat export. If you choose to use one of these options ***be sure that the extension is one which runs locally, not uploading any data to the cloud***.

# %% [markdown]
# ___
#
# ### Submission requirements:
#
# The following are what you are expected to submit:
#
# * Copy of the `.ipynb` notebook file
# * PDF version of the notebook file
#     * On the DataHub, choose `Export as WebPDF`
# * PDF export of Gemini chat logs (if Gemini was used)

# %% [markdown]
# ***
# ## Introduction

# %% [markdown]
# #### **Red-teaming**
#
# As a reminder, [red-teaming](https://en.wikipedia.org/wiki/Red_team) is a cybersecurity exercise where a group poses as an adversary, attempts to disrupt the functionality of some system, then reports to the owners of that system how it might be improved.
#
# Note that here, "adversarial" is a technical term from the discipline of security (both for physical and computer systems). In a red-team process, the teams are actively working **together** to improve the end product, not against each other.
#
# Last week, you used Gemini to write code for counting STRs in DNA sequences. You implemented three functions:
#
# 1. `count_repeats_in_string`: compute the longest run of consecutive repeats of a given STR within a DNA sequence
# 2. `search_database`: search a database of STR profiles for an exact match to a given STR profile
# 3. `STR_search`: search a database of STR profiles for any matches to a given DNA sequence
#
# Additionally, you implemented three testing methods to validate each of the functions listed above:
# 1. `test_STR_counting`
# 2. `test_database_search`
# 3. `test_STR_search`
#
# Next class, we will have you run another group's versions of each function through your tests, determine whether the functions perform as expected, compile a report on your findings, and discuss the results with the authors of the code. All groups will therefore be acting as both the testers and the tested.

# %% [markdown]
# ___
#
# ## This week's assignment: Blue-teaming
#
# You and your group will work together this week to prepare for red-teaming. The actual red-teaming will take place in person during the next class period.
#
# Blue-teaming is the internal, defensive counterpart to red-teaming's external, adversarial testing strategy. A blue team works together on behalf of the targeted system to identify and address errors and vulnerabilities, in an effort to make the system more robust.
#
# This week, you and your team will collaborate on consolidating all of your STR-matching implementations into a single robust version that can be tested by a red team.

# %%
# DO NOT CHANGE THIS CELL
import pandas as pd

# Loading the data
database_df = pd.read_csv("Data/large.csv", index_col="name")
with open("Data/sample-dna.txt") as fp:
    dna_seq = fp.read()

# DO NOT CHANGE THIS CELL
def test_runner(func, test_input: list, expected_output, test_description: str):
    """
    What it does:
        * If the observed output matches the expected output, this function does nothing.
        * If the observed output does not match the expected output, this function prints a helpful log.

    Arguments:
        * func: the name of the function to test
        * test_input: an ordered list of arguments to pass to `func`
        * expected_output: the expected output of running `func` on `test_input` (can pass "ERROR" if a python error is expected to occur)
        * test_description: a helpful description of what this test is doing
    """
    try:
        observed_output = func(*test_input)
    except Exception as e:
        print(repr(e))
        observed_output = "ERROR"
    finally:
        if observed_output != expected_output:
            print(f"FAILED: {test_description}")
            print(f"\tobserved:\t{observed_output}")
            print(f"\texpected:\t{expected_output}")
            print("\tinputs:")
            for x in test_input:
                print(f"\t{x}")
            print("_" * 35)

# %% [markdown]
# ___
# ## `count_repeats_in_string` Implementation and Testing
#
#
# <font color = #d14d0f>**QUESTION 1**:</font> <font color = #0fd12c>**AI PERMITTED**</font>
#
# Create a consolidated version of `count_repeats_in_string` informed by the implementations of everyone in your group. You may base this function on the one submitted by a single group member, but make sure that you understand how the code differs between student submissions. Each member of the group is responsible for ensuring the group submission works correctly. Take care to address any important differences between implementations and incorporate any necessary fixes.

# %%
def count_repeats_in_string(string: str, substring: str) -> int:
    pass

# %% [markdown]
# <font color = #d14d0f>**QUESTION 2**:</font> <font color = #0fd12c>**AI PERMITTED**</font>
#
# Create a consolidated version of `test_STR_counting` based on the implementations of everyone in your group. This version should address all of the tests created by each member of the team in some way, either by directly including all of the `test_runner` calls or by selecting a representative subset that covers all useful test cases. Do not include any incorrect tests. Your final implementation of `count_repeats_in_string` must pass all of the tests in your validation function.
#
# Collect any incorrect tests that you remove in a code block below, and include a python comment which explains why that test was omitted.

# %%
def test_STR_counting():
    pass

# %%
"""COPY ANY INCORECT / OMITTED TESTS HERE"""

# %% [markdown]
# ___
# ## `search_database` Implementation and Testing
#
#
# <font color = #d14d0f>**QUESTION 3**:</font> <font color = #0fd12c>**AI PERMITTED**</font>
#
# Create a consolidated version of `search_database` informed by the implementations of everyone in your group. You may base this function on the one submitted by a single group member, but make sure that you understand how the code differs between student submissions. Each member of the group is responsible for ensuring the group submission works correctly. Take care to address any important differences between implementations and incorporate any necessary fixes.

# %%
def search_database(df: pd.DataFrame, STR_counts: list) -> list:
    pass

# %% [markdown]
# <font color = #d14d0f>**QUESTION 4**:</font> <font color = #0fd12c>**AI PERMITTED**</font>
#
# Create a consolidated version of `test_database_search` based on the implementations of everyone in your group. This version should address all of the tests created by each member of the team in some way, either by directly including all of the `test_runner` calls or by selecting a representative subset that covers all useful test cases. Do not include any incorrect tests. Your final implementation of `search_database` must pass all of the tests in your validation function.
#
# Collect any incorrect tests that you remove in a code block below, and include a python comment which explains why that test was omitted.

# %%
def test_database_search():
    pass

# %%
"""COPY ANY INCORECT / OMITTED TESTS HERE"""

# %% [markdown]
# ___
# ## `STR_search` Implementation and Testing
#
#
# <font color = #d14d0f>**QUESTION 5**:</font> <font color = #0fd12c>**AI PERMITTED**</font>
#
# Create a consolidated version of `STR_search` informed by the implementations of everyone in your group. You may base this function on the one submitted by a single group member, but make sure that you understand how the code differs between student submissions. Each member of the group is responsible for ensuring the group submission works correctly. Take care to address any important differences between implementations and incorporate any necessary fixes.

# %%
def STR_search(database_df: pd.DataFrame, dna_seq: str) -> list:
    pass

# %% [markdown]
# <font color = #d14d0f>**QUESTION 6**:</font> <font color = #0fd12c>**AI PERMITTED**</font>
#
# Create a consolidated version of `test_STR_search` based on the implementations of everyone in your group. This version should address all of the tests created by each member of the team in some way, either by directly including all of the `test_runner` calls or by selecting a representative subset that covers all useful test cases. Do not include any incorrect tests. Your final implementation of `STR_search` must pass all of the tests in your validation function.
#
# Collect any incorrect tests that you remove in a code block below, and include a python comment which explains why that test was omitted.

# %%
def test_STR_search():
    pass

# %%
"""COPY ANY INCORECT / OMITTED TESTS HERE"""

# %% [markdown]
# ---
#
# ### Congratulations! You have finished the notebook! ##
#
# Don't forget to turn in the following:
#
# * Notebook `.ipynb`
# * Notebook `.pdf`
# * Gemini chat log `.pdf`
#
# ---

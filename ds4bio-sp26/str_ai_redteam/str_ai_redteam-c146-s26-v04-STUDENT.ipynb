# %% [markdown]
# # [ds4Bio] STR Matching; AI-assisted coding: Red Teaming
# ### Data Science for Biology
# **Notebook developed by:** *Jeremy Marcus*<br>
# **Supervised by:** *Steven E. Brenner*
#
#
# Previously, we used generative AI to produce code to count STR repeats in a DNA sequence and to match STR profiles, and wrote validation code for testing the functionality of your solutions. This week, we will be performing adversarial testing of each other's code, known as "red teaming".
#
# Through this process, we will identify ways to write better specifications for code, create better validation tests, and more effectively utilize AI tools.
#
# ***

# %% [markdown]
# #### **GROUP PROJECT**
#
# This project must be completed collaboratively with your group and submitted together. All members must contribute for each part of the lab. ***EACH GROUP SHOULD ONLY MAKE A SINGLE SUBMISSION; PLEASE DO NOT SUBMIT SEPARATELY***.
#
# Below, please list your group number and the names of the team members:

# %% [markdown]
# Group Number:
#
# Group Members:
#
# * LIST
# * MEMBERS
# * HERE

# %% [markdown]
# ___
# ### AI Overview
#
# #### Use of AI
#
# Throughout this and future labs, we will be explicit about where use of AI is permitted. There will be three possible options, which will be stated up front for each question:
#
# * <font color = #0fd12c>**AI PERMITTED**</font>
# * <font color = #d1b70f>**AI REQUIRED**</font>
# * <font color = #d14d0f>**NO AI**</font>
#
# Any time you use AI to generate code, ***you are expected to understand what the code is doing***. You may be asked to describe your code.
#
# #### Exporting Chats
#
# When AI tools are used to assist in solving a problem, we will ask for transcripts of any chat sessions as a PDF. Unfortunately, getting Gemini to print a PDF of a chat session while using a CalNet account is not a trivial operation. Here is our suggested solution:
#
# 1. Click the `Tools` button at the bottom of the chat box.
# 2. Select `Canvas`.
# 3. Copy and paste the following into Gemini:
#
# > Please transcribe our entire conversation word-for-word into a new Canvas document
#
# 4. Print to PDF
#
# Alternatively, there are browser-specific extensions that enable chat export. If you choose to use one of these options ***be sure that the extension is one which runs locally, not uploading any data to the cloud***.

# %% [markdown]
# ___
#
# ### Submission requirements:
#
# The following are what you are expected to submit:
#
# * Copy of the `.ipynb` notebook file
# * PDF version of the notebook file
#     * On the DataHub, choose `Export as WebPDF`
# * PDF export of Gemini chat logs (if Gemini was used)

# %% [markdown]
# ***
# ## Introduction

# %% [markdown]
# #### **Red-teaming**
#
# As a reminder, [red-teaming](https://en.wikipedia.org/wiki/Red_team) is an exercise where a group poses as an adversary, attempts to disrupt the functionality of some system, then reports to the owners of that system how it might be improved.
#
# Note that here, "adversarial" is a technical term from the discipline of security (both for physical and computer systems). In a red-team process, the teams are actively working **together** to improve the end product, not against each other.
#
# Previously, you used Gemini to write code for counting STRs in DNA sequences. You implemented three functions:
#
# 1. `count_repeats_in_string`: compute the longest run of consecutive repeats of a given STR within a DNA sequence
# 2. `search_database`: search a database of STR profiles for an exact match to a given STR profile
# 3. `STR_search`: search a database of STR profiles for any matches to a given DNA sequence
#
# Additionally, you implemented three testing methods to validate each of the functions listed above:
# 1. `test_STR_counting`
# 2. `test_database_search`
# 3. `test_STR_search`
#
# This week, as a red team, you will run another group's versions of each function through your validation tests, determine whether the functions perform as expected, compile a report of your findings, and discuss the results with the authors of the code. If there are any validation errors, you will work with the other group to correct their code or your validations as needed, until all work properly.
#
# Likewise, as a blue team, you will meet with the team that evaluated your code, and work with them to correct your code or have them adjust their validation tests until all work properly.
#
# All groups will therefore be acting as both the testers and the tested.

# %%
# DO NOT CHANGE THIS CELL
import pandas as pd
import group_solutions

# Loading the data
database_df = pd.read_csv("Data/large.csv", index_col="name")
with open("Data/sample-dna.txt") as fp:
    dna_seq = fp.read()

# DO NOT CHANGE THIS CELL
def test_runner(func, test_input: list, expected_output, test_description: str):
    """
    What it does:
        * If the observed output matches the expected output, this function does nothing.
        * If the observed output does not match the expected output, this function prints a helpful log.

    Arguments:
        * func: the name of the function to test
        * test_input: an ordered list of arguments to pass to `func`
        * expected_output: the expected output of running `func` on `test_input` (can pass "ERROR" if a python error is expected to occur)
        * test_description: a helpful description of what this test is doing
    """
    try:
        observed_output = func(*test_input)
    except Exception as e:
        print(repr(e))
        observed_output = "ERROR"
    finally:
        if observed_output != expected_output:
            print(f"FAILED: {test_description}")
            print(f"\tobserved:\t{observed_output}")
            print(f"\texpected:\t{expected_output}")
            print("\tinputs:")
            for x in test_input:
                print(f"\t{x}")
            print("_" * 35)

# %% [markdown]
# <font color = #d14d0f>**QUESTION 1a**:</font> <font color = #d14d0f>**NO AI**</font>
#
# Copy the definitions of each of your group's testing functions from the previous lab into the following code block.

# %%
"""PASTE YOUR CODE HERE"""

# def test_STR_counting():
#     pass

# def test_database_search():
#     pass

# def test_STR_search():
#     pass

# %% [markdown]
# <font color = #d14d0f>**QUESTION 1b**:</font> <font color = #d14d0f>**NO AI**</font>
#
# Last week, we asked you to make sure that your code passes all of your own validation tests. On reviewing your submissions, we have observed that some of the groups have not met this criteria. Before continuing, run the following cells to explicitly verify that you pass all of your validation tests.
#
# If you do not pass your own validation tests, figure out what went wrong and address it. If one of your tests is wrong, fix it in this notebook. If your code is wrong, ***it is your job to communicate any fixes to the group who will be testing your code***. Ask a GSI (probably specifically Jeremy) for assistance.
#
# In the following cell, replace `"GROUP_ID"` with `"group_N"`, where `N` is your group's number. For example, Group 1 will put `"group_1"`.

# %%
our_group_id = "GROUP_ID"

# %%
# JUST RUN THIS
def count_repeats_in_string(string: str, substring: str) -> int:
    return group_solutions.count_repeats_in_string[our_group_id](string, substring)

def search_database(df: pd.DataFrame, STR_counts: list) -> list:
    return group_solutions.search_database[our_group_id](df, STR_counts)

def STR_search(database_df: pd.DataFrame, dna_seq: str) -> list:
    return group_solutions.STR_search[our_group_id](database_df, dna_seq)

# %% [markdown]
# Run each of the next cells to run your validation functions on your assigned code.

# %%
test_STR_counting()

# %%
test_database_search()

# %%
test_STR_search()

# %% [markdown]
# ***
# ### 1. Testing

# %% [markdown]
# #### **Group Assignments**
#
# Your group will evaluate the code of the group next to you, moving ***counter-clockwise*** in a circle around the classroom. The following diagram shows the full chain (arrows mean "pass your functions to the next group"):
#
# ```
# 1 ← 2 ← 3 ← 4 ← 5 ← 6 ← 7 ← 9
# ↓                           ↑
# →→→→→→→→→→→→→→→→→→→→→→→→→→→→→
# ```
#
# In the following cell, replace `"GROUP_ID"` with `"group_N"`, where `N` is the number of the group you are evaluating. For example, Group 1, who is evaluating Group 9, will put `"group_9"`.

# %%
testing_group_id = "GROUP_ID"

# %% [markdown]
# Run the next cell to load the implementations you will be evaluating

# %%
# JUST RUN THIS
def count_repeats_in_string(string: str, substring: str) -> int:
    return group_solutions.count_repeats_in_string[testing_group_id](string, substring)

def search_database(df: pd.DataFrame, STR_counts: list) -> list:
    return group_solutions.search_database[testing_group_id](df, STR_counts)

def STR_search(database_df: pd.DataFrame, dna_seq: str) -> list:
    return group_solutions.STR_search[testing_group_id](database_df, dna_seq)

# %% [markdown]
# Run each of the next cells to run your validation functions on your assigned code.

# %%
test_STR_counting()

# %%
test_database_search()

# %%
test_STR_search()

# %% [markdown]
# <font color = #d14d0f>**QUESTION 1c**:</font> <font color = #d14d0f>**NO AI**</font>
#
# The implementations of the code you are assigned to adversarially evaluate can be found in [group_solutions.py](group_solutions.py). With the context of your error report above, take a look at that code and see if you can diagnose the source of any of the errors. This will become part of your response for a later question.
#
# After doing so, write the following message in the box below ***and sign each of your names***:
#
# > Every group member has reviewed the assigned code and thought through what was found.

# %% [markdown]
# DOUBLE-CLICK TO WRITE ACKNOWLEDGMENT AND SIGN NAMES

# %% [markdown]
# Many software errors can be loosely categorized into the following types:
#
# * **Logic Errors**: mistakes in program design lead to unexpected results when the software is run to completion
# * **Input Handling Errors**: software does not cleanly handle all inputs, especially those that are unexpected or not within specification
# * **Syntax Errors**: incorrect usage of the language prevents the code from running, in some or all cases

# %% [markdown]
# Additionally, software errors are often categorized by severity or complexity. Failure to handle an unexpected input might only affect a small number of times the function is run, and adding an extra input check is usually a simple task. If the software is routinely outputting incorrect answers, there might be a larger and more fundamental issue at play.

# %% [markdown]
# Throughout this process, be thoughtful about the tests you wrote and consider whether they are correct. Did the test fail because the implementation is incorrect, or because you wrote a bad test?

# %% [markdown]
# <font color = #d14d0f>**QUESTION 1d**:</font> <font color = #d14d0f>**NO AI**</font>
#
# While testing or reading your assigned code, you may determine that you are missing important tests or have written incorrect tests. If this is the case, make updates to your testing functions below.
#
# If you remove any tests, paste them into the code block below and document why you made changes.
#
# If you add any tests, list them in the markdown block below and describe why you made changes.

# %%
"""WRITE AND RUN UPDATED VERSIONS OF YOUR TESTING FUNCTIONS HERE, IF NECESSARY"""

# %%
"""COPY ANY INCORECT / OMITTED TESTS HERE AND COMMENT WHY YOU REMOVED THEM"""

# %% [markdown]
# DOUBLE-CLICK TO DOCUMENT ADDED TESTS

# %% [markdown]
# <font color = #d14d0f>**QUESTION 1e**:</font> <font color = #d14d0f>**NO AI**</font>
#
# Based on your interpretation of the test results above, write a small report describing the errors you observed. Which test cases failed, and why? Be clear about your findings and provide helpful suggestions for what might need to be fixed.
#
# Consider breaking down the errors by category and severity, and devote more time to any complex logic errors you run into.

# %% [markdown]
# DOUBLE-CLICK TO WRITE YOUR REPORT ABOUT THE TEST RESULTS

# %% [markdown]
# ***
# ### 2. Reporting your results

# %% [markdown]
# Once your group has finished **Part 1**, have a discussion with the group whose code you evaluated. Sit down at the same table and walk through your findings.
#
# Note: While this is a fundamentally "adversarial" testing process to find errors in the code, these discussions should be constructive and supportive. The goal is to work together to figure out how to improve the code and validation.
#
# **This process is only complete once the code passes all validation tests, and both teams are happy with the results**. As part of this process, review your validation tests and theirs; identify any that differ.
#
# As a reminder, if it is helpful to see the code you are assigned to adversarially evaluate, the implementation can be found in [group_solutions.py](group_solutions.py).

# %% [markdown]
# <font color = #d14d0f>**QUESTION 2**:</font> <font color = #d14d0f>**NO AI**</font>
#
# Acknowledge that you have spoken with the group whose code you evaluated, their code and your validations have been adjusted as necessary, and all tests pass.

# %% [markdown]
# DOUBLE-CLICK TO WRITE ACKNOWLEDGMENT AND SIGN NAMES

# %% [markdown]
# ***
# ### 3. Receiving feedback and implementing changes
#
# Once the team evaluating your group's code has finished **Part 1**, they will come to speak with your group about their findings. Sit down at the same table and walk through their findings.
#
# Note: While this is a fundamentally "adversarial" testing process to find errors in the code, these discussions should be constructive and supportive. The goal is to work together to figure out how to improve the code and validation.
#
# **This process is only complete once the code passes all validation tests, and both teams are happy with the results**. As part of this process, review your validation tests and theirs; identify any that differ.
#
# As a reminder, if it is helpful to see the code you are assigned to adversarially evaluate, the implementation can be found in [group_solutions.py](group_solutions.py).

# %% [markdown]
# <font color = #d14d0f>**Question 3**:</font> <font color = #0fd12c>**AI PERMITTED**:</font>
#
# Based on your discussion with the team that tested your code, address any errors that are identified. Note that you may have to make changes to both the STR search code and the validation functions. The final versions of the STR searching code should pass all tests in the final versions of your validation functions.

# %%
"""WRITE AND RUN UPDATED VERSIONS OF YOUR STR SEARCHING FUNCTIONS HERE, IF NECESSARY"""

# %%
"""WRITE AND RUN UPDATED VERSIONS OF YOUR VALIDATION FUNCTIONS, IF NECESSARY"""

# %% [markdown]
# ---
#
# ### Congratulations! You have finished the notebook! ##
#
# Don't forget to turn in the following:
#
# * Notebook `.ipynb`
# * Notebook `.pdf`
# * Gemini chat log `.pdf`
#
# ---
